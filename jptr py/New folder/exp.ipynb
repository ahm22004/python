# %%
# %pip install seaborn
# %pip install upgrade pip
# Out:
# ...
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\shm22004\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
# ...
# ERROR: Could not find a version that satisfies the requirement upgrade (from versions: none)
# ERROR: No matching distribution found for upgrade
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\shm22004\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# %pip install requirement
# Out:
# ERROR: Could not find a version that satisfies the requirement requirement (from versions: none)
# ERROR: No matching distribution found for requirement
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\shm22004\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# %pip install upgrade pip
# Out:
# ERROR: Could not find a version that satisfies the requirement upgrade (from versions: none)
# ERROR: No matching distribution found for upgrade
# WARNING: You are using pip version 21.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'c:\users\shm22004\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
#!pip install tensorflow_model_analysis==0.34.0
#!jupyter labextension install tensorflow_model_analysis@0.34.0
# %pip install Jupyter_widgets
# Out:
# ...
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\users\shm22004\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
# %pip install tfx
# Out:
# ...
#   Using cached tfx-0.23.1-py3-none-any.whl (1.7 MB)
# ...
#   Using cached docker-4.4.4-py2.py3-none-any.whl (147 kB)
# ...
#   Using cached tensorflow_model_analysis-0.23.0-py3-none-any.whl (1.6 MB)
# ...
#   Using cached click-7.1.2-py2.py3-none-any.whl (82 kB)
# ...
#   Using cached pyarrow-0.17.1.tar.gz (2.6 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
#   Using cached pyarrow-0.17.0.tar.gz (3.7 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# ...
#   Using cached tfx-0.23.0-py3-none-any.whl (1.7 MB)
#   Using cached tfx-0.22.2-py3-none-any.whl (1.5 MB)
# ...
#   Using cached apache-beam-2.33.0.zip (2.6 MB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached tfx-0.22.1-py3-none-any.whl (1.5 MB)
#   Using cached tfx-0.22.0-py3-none-any.whl (1.5 MB)
#   Using cached tfx-0.21.5-py3-none-any.whl (1.1 MB)
# ...

# %%
# %pip install dart
# Out:
# ...
#   Attempting uninstall: MarkupSafe
#     Found existing installation: MarkupSafe 1.1.1
#     Uninstalling MarkupSafe-1.1.1:
#       Successfully uninstalled MarkupSafe-1.1.1
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 1.0.1
#     Uninstalling Werkzeug-1.0.1:
#       Successfully uninstalled Werkzeug-1.0.1
#   Attempting uninstall: Jinja2
#     Found existing installation: Jinja2 2.11.3
#     Uninstalling Jinja2-2.11.3:
#       Successfully uninstalled Jinja2-2.11.3
# ...

# %%
# !dir dart
# Out:
#  Volume in drive C is OS
# File Not Found
#  Volume Serial Number is 70C1-9391
#
#  Directory of c:\shemies\E_Drive\python\jptr py\New folder

# %%
#!pip install witwidget
#!pip install jupyter
# %labextension install wit-widget
# %labextension install @jupyter-widgets/Jupyter-manager
# Out:
# UsageError: Line magic function `%labextension` not found.

# %%
# %pip install -U ipykernel
# Out:
# ...
#      ------------------------------------ 128.9/128.9 KB 631.1 kB/s eta 0:00:00
# ...
#      -------------------------------------- 102.0/102.0 KB 2.0 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 4.4/4.4 MB 1.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.0.5
#     Uninstalling traitlets-5.0.5:
#       Successfully uninstalled traitlets-5.0.5
#   Attempting uninstall: ipykernel
#     Found existing installation: ipykernel 5.5.5
#     Uninstalling ipykernel-5.5.5:
#       Successfully uninstalled ipykernel-5.5.5
# ...
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the 'C:\users\shm22004\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.
